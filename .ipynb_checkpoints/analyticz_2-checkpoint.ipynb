# %%
# %pylab inline
# %load_ext autoreload
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pn_analyze

# %%
import cProfile

# %%
import os
import time
import socket
import sqlite3
import datetime

from collections import OrderedDict,namedtuple

import bokeh
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt

from sqlalchemy import create_engine
from bokeh.plotting import figure, output_notebook, show
matplotlib.style.use('ggplot')

# %%
import pn_analyze, _data, _graphs

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.charts import Bar, output_file, show
import bokeh.charts as chart

# %%
DB_FILE_LOCATION='/home/jshank/ext/code/pynet_database.db'
now = datetime.datetime.now()
REGEX_PATTERN_GCI =  r'[A-Z]\w{5,7}'
TIMESTAMP_PARSE_DICT = {'case_timestamp': '%Y-%m-%dT%H:%M:%S.%fZ'}

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0c40b063-8f68-45cf-a423-74bf7f6c1036">Loading BokehJS ...</span>
#     </div>

# %%
disk_engine = create_engine('sqlite:///%s' % DB_FILE_LOCATION)
def loadup_func(disk_engine):
    metrics = pn_analyze.TestResult(disk_engine)
    metrics.strict_startup()
    return metrics

# %%
b = time.time()
metrics = loadup_func(disk_engine)
print(time.time() - b)
# Out:
# 301.9976325035095

# %%
metrics.this_year
# Out:
# 393     False
# 394     False
# 395     False
# 561     False
# 748     False
# 749     False
# 750     False
# 751     False
# 752     False
# 753     False
# 754     False
# 757     False
# 758     False
# 759     False
# 760     False
# 761     False
# 762     False
# 763     False
# 792     False
# 793     False
# 794     False
# 795     False
# 1228    False
# 1229    False
# 1230    False
# 1398    False
# 1601    False
# 1602    False
# 1603    False
# 1604    False
#         ...
# 4005     True
# 4006     True
# 4007     True
# 4008     True
# 4009     True
# 4010     True
# 4011     True
# 4014    False
# 4015    False
# 4016    False
# 4017    False
# 4018    False
# 4019    False
# 4020    False
# 4021    False
# 4022     True
# 4023     True
# 4024     True
# 4025     True
# 4026     True
# 4027     True
# 4028     True
# 4031    False
# 4032    False
# 4033    False
# 4034    False
# 4035    False
# 4036    False
# 4037    False
# 4038    False
# Name: case_timestamp, dtype: bool

# %%
dis_year = metrics.df[metrics.this_year]
# by_case_action = dis_year.groupby('case_action')
# by_guid = dis_year.groupby('group_uuid')
# latest = dis_year[dis_year.group_uuid.isin([_data.return_guuid_latest(dis_year)])]

# %%
latest = dis_year[dis_year.group_uuid.isin([_data.return_guuid_latest(dis_year)])]

# %%
len(metrics.df[metrics.df.group_uuid == '16d5322813624f8e8449ef803b69bbab'].case_id.unique())
# Out:
# 830

# %%
len(metrics.df[metrics.df.group_uuid == 'fe0d174bb5544e669141a048c6e7e164'])
# Out:
# 15

# %%
latest[_data.return_in_norm_df(latest, 'case_duration', 2)]
# Out:
#                             group_uuid                     scenario_uuid  \
# 4023  fe0d174bb5544e669141a048c6e7e164  d58643dcc0b9455aa7cb181d86512218
# 4024  fe0d174bb5544e669141a048c6e7e164  d58643dcc0b9455aa7cb181d86512218
# 4025  fe0d174bb5544e669141a048c6e7e164  d58643dcc0b9455aa7cb181d86512218
# 4026  fe0d174bb5544e669141a048c6e7e164  d58643dcc0b9455aa7cb181d86512218
# 4027  fe0d174bb5544e669141a048c6e7e164  d58643dcc0b9455aa7cb181d86512218
# 4028  fe0d174bb5544e669141a048c6e7e164  d58643dcc0b9455aa7cb181d86512218
#
#                              case_uuid   case_service_name       case_id  \
# 4023  3bf9824419754acc9d749bed23c7d173  BOLTServicesBranch  020-001-0002
# 4024  f6d1b01d2228489cb7fc1d49d9cdec1e  BOLTServicesBranch  020-001-0003
# 4025  17b1d310418c48f1a52f33c0d86a046d  BOLTServicesBranch  020-001-0004
# 4026  287b5464961c4731a3ad8dff6ee49036  BOLTServicesBranch  020-001-0005
# 4027  a62255262ba94a9eaa507e6318a836e0  BOLTServicesBranch  020-001-0006
# 4028  1495748cc7c7471480f60eed8027493c  BOLTServicesBranch  020-001-0007
#
#                                        case_description  \
# 4023                                GET Navigate to DIS
# 4024                                POST Search for DIS
# 4025                                    POST DIS Submit
# 4026  DIS v2, submit small pdf to customs successful...
# 4027  DIS v2, Find after successful transmit to ensu...
# 4028                                POST Replace of DIS
#
#                  case_timestamp case_status case_client_ip  \
# 4023 2016-10-14 14:00:45.008847      passed   10.1.178.201
# 4024 2016-10-14 14:00:45.084846      passed   10.1.178.201
# 4025 2016-10-14 14:00:45.156847      passed   10.1.178.201
# 4026 2016-10-14 14:00:45.381847      passed   10.1.178.201
# 4027 2016-10-14 14:05:45.659847      failed   10.1.178.201
# 4028 2016-10-14 14:05:45.718847      passed   10.1.178.201
#
#                case_endpoint   case_action  case_duration  numeric_status  \
# 4023  qacombo016.dr1.ei:8121      new.test          0.038               1
# 4024  qacombo016.dr1.ei:8121   search.test          0.064               1
# 4025  qacombo016.dr1.ei:8121   submit.test          0.060               1
# 4026  qacombo016.dr1.ei:8121   submit.test          0.181               1
# 4027  qacombo016.dr1.ei:8121   search.test          0.263               0
# 4028  qacombo016.dr1.ei:8121  replace.test          0.044               1
#
#       failed  passed  skipped             date_int
# 4023       0       1        0  1476453645008847000
# 4024       0       1        0  1476453645084846000
# 4025       0       1        0  1476453645156847000
# 4026       0       1        0  1476453645381847000
# 4027       1       0        0  1476453945659847000
# 4028       0       1        0  1476453945718847000

# %%
met

# %%
fig, ax = plt.subplots(figsize=(20,5))
metrics.df[metrics.this_month].case_action.value_counts().plot(kind='bar', ax=ax, color='gray')
ax.set_title('Coverage by Endpoint')

# %%
from bokeh.charts import Histogram, output_file, show
from bokeh.sampledata.autompg import autompg as df
import bokeh.plotting as bk

hist = Histogram(df, values='hp', color='cyl',
                 title="HP Distribution by Cylinder Count", legend='top_right')

# %%
h = chart.Histogram(latest.case_action.map(hist_map), bins = 2*len(hist_map))
h.xaxis[0].formatter = FixedTickFormatter(labels=inv_map)
show(h)
# Out:
# ------------------------------------------------------------------------
# NameError                              Traceback (most recent call last)
# <ipython-input-20-4e568d85a225> in <module>()
# ----> 1 h = chart.Histogram(latest.case_action.map(hist_map), bins = 2*len(hist_map))
#       2 h.xaxis[0].formatter = FixedTickFormatter(labels=inv_map)
#       3 show(h)
#
# NameError: name 'hist_map' is not defined

# %%
pf_metrics = metrics.df[(metrics.df.numeric_status !=3) & metrics.this_month]

# %%
caseidgroup = pf_metrics.groupby('case_id')
ssorted = caseidgroup.numeric_status.mean()
ssorted.sort_values()[:10]
# Out:
# case_id
# 414-024-0001    0.0
# 404-022-0001    0.0
# 404-021-0001    0.0
# 404-020-0001    0.0
# 404-003-0001    0.0
# 404-002-0001    0.0
# 404-001-0001    0.0
# 403-027-0001    0.0
# 403-026-0001    0.0
# 403-025-0001    0.0
# Name: numeric_status, dtype: float64

# %%
def highest_failures_by_groupby_count(groupby_df, count):
    mean_status = groupby_df.numeric_status.mean()
    worst = mean_status.sort_values()[:count]
    return worst

# %%
def highest_failures_by_groupby_stdev(groupby_df, sigma=0):
    vals = groupby_df.numeric_status.mean()
    normed_vals = vals[~_data.return_in_norm_series(vals, sigma)]
    not_pass_fail_100 = normed_vals[(normed_vals <= 0.95) & (normed_vals != 0)]
    print(type(not_pass_fail_100))
    return not_pass_fail_100

# %%
def bar_plot_w_numeric_status(groupby_df, sigma=0):
    fig, ax = plt.subplots(figsize=(20,10))
    not_pass_fail_100 = highest_failures_by_groupby_stdev(groupby_df, sigma)
    ax.bar(np.arange(len(not_pass_fail_100)), not_pass_fail_100)
    ax.set_xticks(np.arange(len(not_pass_fail_100))+0.5)
    ax.set_xticklabels(not_pass_fail_100.keys(), rotation=80)
    return fig, ax, not_pass_fail_100.keys()

# %%
fig, ax, list_keys = bar_plot_w_numeric_status(pf_metrics.groupby('case_id'), 1.8)
ax.set_title('Highest % of Failures by Test ID')
# Out:
# <class 'pandas.core.series.Series'>

# %%
hardy = pf_metrics[(pf_metrics.numeric_status == 0) | (pf_metrics.numeric_status == 1)].groupby('case_id').numeric_status.mean()

# %%
p = Bar(highest_failures_by_groupby_count(metrics.df.groupby('case_id'), 20), plot_width=800, plot_height=500, legend=None, 
        title='Lowest 20 Passing Rate Case Ids for Current Month', ylabel='Pass Rate')

# %%
p = Bar(highest_failures_by_groupby_stdev(pf_metrics.groupby('case_id'), 1.5))
show(p)
# Out:
# <class 'pandas.core.series.Series'>
#     <div class="bk-root">
#         <div class="plotdiv" id="84f1ff79-f59d-4645-a0a2-1f3c23566e89"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#84f1ff79-f59d-4645-a0a2-1f3c23566e89").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("84f1ff79-f59d-4645-a0a2-1f3c23566e89");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '84f1ff79-f59d-4645-a0a2-1f3c23566e89' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"78a15a9a-1533-4921-b7b2-e6735054efe0":{"roots":{"references":[{"attributes":{"label":{"value":"412-024-0001"},"renderers":[{"id":"e565314d-8cbb-4663-98f7-1b146ce8c720","type":"GlyphRenderer"}]},"id":"32bc69aa-4dc8-4553-99fa-8106c56a2289","type":"LegendItem"},{"attributes":{"data_source":{"id":"f98b291a-a142-489c-894f-6a5011d7849f","type":"ColumnDataSource"},"glyph":{"id":"879e8231-66b3-4b97-8b36-44eebf4c8a9f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0627e06d-c6c3-4417-80c3-f7c8df7b8182","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","line_alpha","height","label","fill_alpha","width","color","line_color"],"data":{"chart_index":[{"index":"033-007-0001"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.09523809523809523],"index":["033-007-0001"],"label":[{"index":"033-007-0001"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["033-007-0001"],"y":[0.047619047619047616]}},"id":"bccca88c-8f85-4658-9f72-0d79123bb35d","type":"ColumnDataSource"},{"attributes":{"label":{"value":"407-015-0001"},"renderers":[{"id":"e9d88672-af0d-4b2c-84b9-073080ca7c5d","type":"GlyphRenderer"}]},"id":"7e49710d-ee7b-4e06-9c9a-6b8040b1041f","type":"LegendItem"},{"attributes":{"plot":{"id":"501dff21-1917-4bcc-9669-05a024cf518c","subtype":"Chart","type":"Plot"}},"id":"8ed277f9-a464-4fbf-96a7-97d4e8023067","type":"SaveTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"80ab3ba8-cb09-4789-abc3-568b958313e1","type":"Rect"},{"attributes":{"data_source":{"id":"f87240bb-cb63-4a6b-a887-08acf6502393","type":"ColumnDataSource"},"glyph":{"id":"8d843fb3-e805-4b88-9779-f63a0db403ac","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"33f40b84-f0ed-4e1e-9e2b-40570f9f0a7f","type":"GlyphRenderer"},{"attributes":{"label":{"value":"033-008-0001"},"renderers":[{"id":"701b3a38-5591-4854-86d6-e1b1e6d5f80b","type":"GlyphRenderer"}]},"id":"49a31f7d-5951-458c-8c7c-de412b603f54","type":"LegendItem"},{"attributes":{"label":{"value":"033-002-0001"},"renderers":[{"id":"5ab5c774-294b-4f07-bf9e-afb63b7ab9ae","type":"GlyphRenderer"}]},"id":"1c198acc-a573-43ee-a15c-d1400628a4f5","type":"LegendItem"},{"attributes":{"data_source":{"id":"ec6270c1-d1e5-454b-b3f4-23aef5992cc9","type":"ColumnDataSource"},"glyph":{"id":"bb9dd19b-865e-47b8-81e2-ec8d32b838c6","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1271822f-0d7b-4510-850d-0459d72e8fbe","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","line_alpha","height","label","fill_alpha","width","color","line_color"],"data":{"chart_index":[{"index":"409-017-0001"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.25],"index":["409-017-0001"],"label":[{"index":"409-017-0001"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["409-017-0001"],"y":[0.125]}},"id":"e630f725-4732-4b4e-889e-06048242e09b","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d5299c12-8f92-4eb8-b806-433d0fd42627","type":"Rect"},{"attributes":{"axis_label":"Sum( Numeric_Status )","formatter":{"id":"94842781-6cd0-482f-bfc9-fce553ba90c6","type":"BasicTickFormatter"},"plot":{"id":"501dff21-1917-4bcc-9669-05a024cf518c","subtype":"Chart","type":"Plot"},"ticker":{"id":"a76531e0-8ba4-4641-8ebb-a9d097b406e0","type":"BasicTicker"}},"id":"af71294c-42f5-42c1-aecc-4c18f8abd5ba","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["x","y","line_alpha","height","label","fill_alpha","width","color","line_color"],"data":{"ch ...

# %%
len(metrics.df.case_description.unique())
# Out:
# 3660

# %%
boop = highest_failures_by_groupby(pf_metrics.groupby('case_id'), 1.5)

# %%
aggregation = {
    'case_duration' : {
        'mean_duration': 'mean',
        'std_dev': 'std'
    }
}
groupby_id = metrics.df.groupby('case_id')
mean_duration_df = groupby_id.agg(aggregation).dropna()
max_duration= mean_duration_df[(mean_duration_df.case_duration.mean_duration == 
                                                   mean_duration_df.case_duration.mean_duration.max())]
max_duration_over_time = _data.return_specific_case_over_time(metrics.df, max_duration.index.values[0])

# %%
max_duration_over_time.head()
# Out:
#                             group_uuid                     scenario_uuid  \
# 8764  be92424ed04841d6bd9a78ec63c8f566  290f4214f7dc4fd1bfa59e247bb589e8
# 4224  96630da5cc764eee8113e4bd87a30a61  fbb33e86d3d747f181ebf937760a8bfe
# 427   e1a9fa7befb54fcdaa7f1c2e972d62dd  71037bafd852491792a6fb406851f454
# 2861  c317103bdbde49f0a1cbb9551c508ab9  9b6c212404164447af3cb0b9118c80e3
# 7941  3a52a2f0a9a3493a95f8c84b8c4b42a0  0e8f820d91ea4eac9698e604b0d23bc2
#
#                              case_uuid   case_service_name       case_id  \
# 8764  f0a74a3813aa4054a4613d31f8aa235e  BOLTServicesBranch  090-006-0008
# 4224  d6ddd3234b3949a787e34b09004735b8  BOLTServicesBranch  090-006-0008
# 427   139376db459d4745a81f579830cd372d  BOLTServicesBranch  090-006-0008
# 2861  1cb43057f5214cee921eac476035fe3c  BOLTServicesBranch  090-006-0008
# 7941  f4d99b23e1de46a4ae8b09487ceff211  BOLTServicesBranch  090-006-0008
#
#                                        case_description  \
# 8764  BNA performance testing: 6 invoices 350 lines\...
# 4224  BNA performance testing: 6 invoices 350 lines\...
# 427   BNA performance testing: 6 invoices 350 lines\...
# 2861  BNA performance testing: 6 invoices 350 lines\...
# 7941  BNA performance testing: 6 invoices 350 lines\...
#
#                  case_timestamp case_status case_client_ip   case_endpoint  \
# 8764 2016-09-19 17:06:44.742122      failed   10.1.178.201  localhost:8080
# 4224 2016-10-10 10:14:48.855080      failed   10.1.178.201  localhost:8080
# 427  2016-10-10 15:47:28.466492      failed   10.1.178.201  localhost:8080
# 2861 2016-10-10 17:49:22.612555     skipped    10.1.179.46
# 7941 2016-10-14 10:43:50.883310      failed   10.1.178.201  localhost:8080
#
#         case_action  case_duration  numeric_status  failed  passed  skipped  \
# 8764  transmit.test      28.794879               0       1       0        0
# 4224  transmit.test     162.227508               0       1       0        0
# 427   transmit.test       0.028000               0       1       0        0
# 2861                      0.000000               2       0       0        1
# 7941  transmit.test     137.908789               0       1       0        0
#
#                  date_int
# 8764  1474304804742122000
# 4224  1476094488855080000
# 427   1476114448466492000
# 2861  1476121762612555000
# 7941  1476441830883310000

# %%
def plot(df, fig, ax):
    if df.case_client_ip.unique() == 1:
        case_client_ip = df.case_client_ip.unique()[0]
        try:
            hostname = get_hostname(case_client_ip)
        except:
            hostname = case_client_ip
    else:
        hostname = None
    df.plot('date_int', 'case_duration', kind='scatter', ax=ax, color=np.random.rand(3,1), label=hostname)
#     xtick_range = (over_time.dropna().date_int.max() - over_time.dropna().date_int.min()) / 10
#     current_xticks = [a.get_text() for a in ax.get_xticklabels()]
    d = list(map(lambda x: pd.to_datetime(x).strftime('%m-%d-%Y'), ax.get_xticks()))
    ax.set_xticklabels(d, rotation=70)
    ax.set_title('.'.join(df.case_id.unique()))

# %%
fig, ax = plt.subplots(figsize=(20,10))
plot(_data.return_longest_case_over_time(metrics.df[(metrics.df.case_endpoint.str.contains('localhost')) & 
                                            (metrics.df.case_client_ip == '10.1.178.183') & (metrics.df.passed == 1)],
                                   aggregation), fig, ax)

# %%
a = _data.return_longest_case_over_time(metrics.df[metrics.df.case_endpoint.str.contains('qacombo016')], aggregation)
b = _data.return_in_norm_df(a, 'case_duration', 1)
len(a[b])
a = cm.get_cmap('nipy_spectral')

# %%
fig, ax = plt.subplots(figsize=(20,10))
t = 0
for ip in metrics.df.case_client_ip.unique():
    if ip:
#         print(ip)
        plot(_data.return_longest_case_over_time(metrics.df[(metrics.df.case_endpoint.str.contains('localhost')) & 
                                                    (metrics.df.case_client_ip == ip) & (metrics.df.passed == 1)], aggregation), fig, ax)
        t+=1
# Out:
# ------------------------------------------------------------------------
# IndexError                             Traceback (most recent call last)
# <ipython-input-42-cf4c2189e9d2> in <module>()
#       5 #         print(ip)
#       6         plot(_data.return_longest_case_over_time(metrics.df[(metrics.df.case_endpoint.str.contains('localhost')) &
# ----> 7                                                     (metrics.df.case_client_ip == ip) & (metrics.df.passed == 1)], aggregation), fig, ax)
#       8         t+=1
#
# /home/jshank/ext/code/expd_analytics/_data.py in return_longest_case_over_time(df, aggregation)
#     158     max_duration = mean_duration_df[(mean_duration_df.case_duration.mean_duration ==
#     159                                                    mean_duration_df.case_duration.mean_duration.max())]
# --> 160     max_duration_over_time = return_specific_case_over_time(df, max_duration.index.values[0])
#     161     return max_duration_over_time
#     162
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
plt.scatter(metrics.df.date_int, metrics.df.case_duration, cmap='Blues', c=range(len(metrics.df.date_int)))

# %%
def return_mean_duration_over_time(df):
    mean_time_v_endpoint = df.groupby('case_endpoint')
    mean_v_endpoint = mean_duration_v_case_endpoint.agg(aggregation)

# %%
mean_time_v_endpoint = metrics.df.groupby('case_endpoint')
mean_v_endpoint = mean_time_v_endpoint.agg(aggregation)
mean_v_endpoint['ticks'] = pd.Series(range(len(mean_v_endpoint.index.values)), index=mean_v_endpoint.index)

# %%
fig, ax = plt.subplots(figsize=(20,10))
plt.scatter(range(len(mean_v_endpoint.index.values)), mean_v_endpoint.case_duration.mean_duration)
ax.set_xticks(_graphs.create_uniform_tcks(mean_v_endpoint.index.values))
ax.set_xticklabels(mean_v_endpoint.index.values, rotation = 70)
# Out:
# [<matplotlib.text.Text at 0x7f6ed90edda0>,
#  <matplotlib.text.Text at 0x7f6ed8ce25c0>,
#  <matplotlib.text.Text at 0x7f6ed929bf28>,
#  <matplotlib.text.Text at 0x7f6ed929b4e0>,
#  <matplotlib.text.Text at 0x7f6ed9a446a0>,
#  <matplotlib.text.Text at 0x7f6ed9af4940>,
#  <matplotlib.text.Text at 0x7f6ed93a9400>,
#  <matplotlib.text.Text at 0x7f6ed93eb588>,
#  <matplotlib.text.Text at 0x7f6ed941dac8>,
#  <matplotlib.text.Text at 0x7f6ed941d080>,
#  <matplotlib.text.Text at 0x7f6ed93f6550>,
#  <matplotlib.text.Text at 0x7f6ed9463ac8>,
#  <matplotlib.text.Text at 0x7f6ed9441ef0>,
#  <matplotlib.text.Text at 0x7f6ed9441278>,
#  <matplotlib.text.Text at 0x7f6ed948b630>,
#  <matplotlib.text.Text at 0x7f6ed9555f98>,
#  <matplotlib.text.Text at 0x7f6ed953bda0>,
#  <matplotlib.text.Text at 0x7f6ed959fe48>,
#  <matplotlib.text.Text at 0x7f6ed9584ef0>,
#  <matplotlib.text.Text at 0x7f6ed95eac88>,
#  <matplotlib.text.Text at 0x7f6ed95cea20>,
#  <matplotlib.text.Text at 0x7f6ed95c0048>,
#  <matplotlib.text.Text at 0x7f6ed96101d0>,
#  <matplotlib.text.Text at 0x7f6ed964f710>,
#  <matplotlib.text.Text at 0x7f6ed96aec88>,
#  <matplotlib.text.Text at 0x7f6ed96ae198>,
#  <matplotlib.text.Text at 0x7f6ed967d710>]

# %%
(len(metrics.df) - len(metrics.df[metrics.df.case_timestamp.isnull()])) / len(metrics.df)
# Out:
# 0.9158772674388115

# %%
count_agg = {
    'scenario_uuid' : {
        'count': 'count'
    }
}

# %%
def _get_case_count_by_service(df):
    service_names = df.case_service_name.unique()
    count_frame = df.groupby(['case_service_name', 'group_uuid']).agg({'scenario_uuid' : {'count': 'count'}})
    service_v_count = {}
    for service in service_names:
        serv_frame = count_frame.loc[service]
        max_scenario_uuid = serv_frame.scenario_uuid.max()
        largest_guiid = serv_frame.scenario_uuid[serv_frame.scenario_uuid == max_scenario_uuid].dropna().index.values
        largest_run = df[df.group_uuid ==  largest_guiid[0]]
        full_name = largest_run.case_service_name.str.cat(largest_run.case_id, sep='_')
        case_count = len(full_name.unique())
        service_v_count[service] = case_count
    return service_v_count

# %%
def get_case_list_by_group(config):
#     Identity = namedtuple('Identity', ['service', 'id'])
    groups = config.get('groups')
    full_case_lists = {}
    for group_name, group in groups.items():
        cases = group['cases']
        if group.get('dependencies'):
            for dep in group.get('dependencies'):
                dependencies_tests = groups.get(dep).get('cases')
                cases +=  dependencies_tests
        full_case_lists[group_name] = cases
    return full_case_lists

# %%
import json
with open('config.json', 'rb') as in_file:
    config = json.loads(in_file.read().decode())
# Out:
# ------------------------------------------------------------------------
# FileNotFoundError                      Traceback (most recent call last)
# <ipython-input-51-43f2b93eb91f> in <module>()
#       1 import json
# ----> 2 with open('config.json', 'rb') as in_file:
#       3     config = json.loads(in_file.read().decode())
#
# FileNotFoundError: [Errno 2] No such file or directory: 'config.json'

# %%
_get_case_count_by_service(metrics.df)
# Out:
# {'BOLTServicesBranch': 1046,
#  'BOLTServicesRefData': 618,
#  'CustomsRefServiceBranch': 1726,
#  'CustomsWebServiceBranch': 1742,
#  'CustomsWebServiceCHQ': 1,
#  'GlobalCompanyIdentifierService': 5}

# %%
count_frame = metrics.df.groupby(['case_service_name', 'group_uuid']).agg(count_agg)

# %%
bolt = count_frame.loc['BOLTServicesBranch']

# %%
biggest_guiid = bolt.scenario_uuid[bolt.scenario_uuid == bolt.scenario_uuid.max()].dropna().index[0]

# %%
metrics.df[metrics.df.group_uuid == biggest_guiid].case_id.unique()
# Out:
# array(['001-001-0001', '001-001-0002', '001-001-0003', ..., '051-001-0002',
#        '051-001-0003', '051-001-0004'], dtype=object)

# %%
count_frame.loc['BOLTServicesBranch'].scenario_uuid.describe().max().values
# Out:
# array([ 6276.])

# %%
count_frame.loc['BOLTServicesBranch'].scenario_uuid.max()
# Out:
# count    6276
# dtype: int64

# %%
count_frame.loc['BOLTServicesBranch'].scenario_uuid[count_frame.loc['BOLTServicesBranch'].scenario_uuid ==6276].dropna().index.values
# Out:
# array(['3a4f6c117d11431f9e54804240f43350'], dtype=object)
